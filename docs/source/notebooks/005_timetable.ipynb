# %% [markdown]
# Notebook created: 2026-03-02 11:27:16
# Generated from: source/005_timetable.rst

# %% [markdown]
# <a id='timetable'></a>

# %% [markdown]
# # Timeplan KI verksted 24. juni 2025
#
# [Nettsted på UiO](https://www.ub.uio.no/kurs-arrangement/kurs/gpt-uio/kjor-store-sprakmodeller-gjennom-educloud-uio.html).

# %% [markdown]
# ## Forkunnskaper
#
# 1. Alle deltakere har en ferdig testet konto på [Educloud On Demand](https://ondemand.educloud.no/).
# 1. Carpentry leksjonen [Plotting and Programming in Python](https://swcarpentry.github.io/python-novice-gapminder/). bør tas som selvstudiom, om du ikke har deltatt i egen person.
# 1. Finn fram skjermtasteturet på maskinen din.

# %% [markdown]
# ## Alle må ha med
#
# - Egen bærbar PC
# - En smarttelefon med [denne autentiserings appen](https://www.microsoft.com/nb-no/security/mobile-authenticator-app). Testet og klar til bruk, som betyr at du har vært inne i Educloud On Demand.
# - Lurt1: koble seg til [samarbeidsdokumentet](https://hackmd.okfn.de/AOCRq-OwTfWaTbbVaD9aBQ#), dersom vi blir enige om å bruke det.
# - Lurt2: [Huggingface url](https://huggingface.co/)
#
#
# Timeplanen under er tentativ. Vi tilpasser underveis.

# %% [markdown]
# ## Før lunsj
#
# **09:15-10:00**
# [Oppstart](01_easy_login.ipynb) og [Installering](02_downloading_packages.ipynb)
#
# **10:15-11:00**
# [Instruks til Store Språkmodeller (Chatboter)](03_chatbot.ipynb)
#
# **11:15-11:45**
# [Oppsummeringer](04_summarization.ipynb)
#
# **11:45-12:15**
# Lunch

# %% [markdown]
# ## Etter lunsj
#
# **12:15-14:00**
# [Retrieval-Augmented Generation (RAG)](05_rag.ipynb)
#
# Hvis vi får tid, last opp eget materiale, og du kan prøve å bruke metodene som du har lært på eget materiale. Vi hjelper hverandre.
#
# Velkommen!
# Hilsen Pål, Erik og Ragnhild
