# %% [markdown]
# .. _tidtabell:
#
# Hei hå, nå er det jul igjen
# ============================
#
# # Timetable AI workshop June 24th 2025
#
# ## Prerequisites
# 1) All participants should have a working and tested account at Educloud on Demand. Follow the instructions [here](notebooks/01_preparations.ipynb).
#
# 2) The Carpentry lesson on [Plotting and Programming in Python]
# https://swcarpentry.github.io/python-novice-gapminder may be done as a self study. We recommend doing chapters one and six as a minimum.
#
# 3) Find your screen keyboard on your computer. You are going to need it.
#
# ## Everybody must bring
# * A laptop
# * A smartphone with [this Authenticator](https://www.microsoft.com/nb-no/security/mobile-authenticator-app). Tested and ready for use in Educloud on demand.
#
# ## Before lunch
# **09:15-10:00**
#
# [03 Installing software](03_installing.ipynb)
#
# ### Med opplenking til label
#
# :ref:`detailed-preparations`
#
# :doc:`detailed-preparations`
#
# ### Bilde opplenking med sphinx
#
# .. image:: grobelska.jpg
#
# .. image:: sleiman.jpg
#
#
# **10:15-11:00**
# :doc:`notebooks/04_chatbot`
#
# **11:15-11:45**
# :doc:`notebooks/05_summarization`
#
# **11:45-12:15**
# Lunch
#
# ## After lunch
# **12:15-13:00**
# [Summarization](https://uio-library.github.io/LLM-course/3_summarizing.html)
#
# **13:15-13:45**
# [Retrieval Augmented Generation (RAG)](https://uio-library.github.io/LLM-course/4_RAG.html)
#
# **13:45-14:00**
# [Evaluering](https://nettskjema.no/a/llm-course)
#
# .. todo:: 02 Evaluering
#
# If we get time, upload your own material, and you may try to use the methods on what you have. The instructors will assist you.
#
# Welcome, this will be fun!
# From Erik and Ragnhild
#
# ## Evaluation form
# We are inviting you to continue using Educloud ec443 until Desember 2025. Please use the red and green sticky notes that you were given. Write what we can do better on the red one, and what you appreciated, on the green one.
