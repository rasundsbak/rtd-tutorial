# %% [markdown]
# # Installering
#
# Vi kommer til å bruke [LangChain](https://www.langchain.com/) , et bibliotek med åpen kildekode, som brukes til å lage
# applikasjoner med LLMer. Vi vil bruke modeller fra [HuggingFace](https://huggingface.co/), en nettside som har verktøy og modeller som brukes til maskinlæring.

# %% [markdown]
# ```{admonition} Oppgave 3.1: Lag en ny notebook
#
# Lag en ny Jupyter Notebook med navn `installing` ved å klikke Filmenyen i JupyterLab, og så “New” og “Notebook”. Hvis du blir spurt om å velge en kjerne (kernel), velg “Python 3”. Gi navn til notebooken ved å klikke Filmenyen i JupyterLab og deretter “Rename Notebook”. Bruk navnet `installing`.
# ```
#
# ```{admonition} Virtuelle miljøer
# :class: warning
#
# Hvis du vanligvis jobber med [virtuelle miljøer](https://docs.python.org/3/library/venv.html) på Fox, bør du sette opp og aktivere et virtuelt miljø før du fortsetter. Se i {ref}`bonus-venv`, lenger nede på denne siden. Hvis du ikke har hørt om virtuelle miljøer, kan du fortsette uten å bruke virtuelle miljøer.
# ```

# %% [markdown]
# ## Pyton pakker
#
# Vi kommer til å bruke pakkeinstallasjonsprogrammet ``pip``til å installere programvare. ``pip``installerer programvare fra [Python package index](https://pypi.org/) . Først oppdaterer vi ``pip``til den nyeste versjonen:

# %%
# Hvor installerer jeg pakkene mine?
import sys
print(sys.executable)
# Out:
# /Users/ragnhildsundsbak/rtd-tutorial/.venv/bin/python

# %%
# Finne .venv'er med tanke på rydding find ~ -type d -name "venv" -o -name ".venv"

# %%
pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (21.2.4)
# Collecting pip
#   Downloading pip-26.0.1-py3-none-any.whl (1.8 MB)
#      |████████████████████████████████| 1.8 MB 3.6 MB/s eta 0:00:01
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 21.2.4
#     Uninstalling pip-21.2.4:
#       Successfully uninstalled pip-21.2.4
# Successfully installed pip-26.0.1
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Requirements fil
#
# I desember 2025, hadde vi problemer med at noen av våre viktigste biblioteker ikke lenger ble vedlikeholdt. Dette gjorde at vi utviklet en requirements fil. Behovet for denne gjenoppstod i april 2026. Kjør koden under:

# %%
# pip install -r /fp/projects01/ec443/LLM-requirements.txt

# %% [markdown]
# ```{admonition} Virtuelle miljøer
# :class: warning
#
# Requirements filen gjør at alle pakkene installerer seg selv i en versjon som ikke gir deg problemer. Hopp over resten av dette kapittelet. Skulle du senere ønske å oppdatere python pakkene, kan du kjøre koden under.
# ```

# %% [markdown]
# ### Nevrale nettverk og programvare
#
# Språkmodeller er en slags neurale nettverk. Vi kommer til å bruke Python pakken PyTorch til å kjøre modellene våre.

# %% [markdown]
# ### Generell LLM programvare
#
# Vi kommer til å installere LangChain og Ollama programmer først. Vi bruker `Ollama`til å automatisk laste ned modeller når dette nødvendig.

# %%
# pip install --upgrade huggingface-hub
# pip3 uninstall huggingface_hub -y
# !pip3 uninstall langchain-classic -y
# Out:
# WARNING: Skipping langchain-classic as it is not installed.

# %%
pip install --upgrade pypdf
# Out:
# Requirement already satisfied: pypdf in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (6.14.2)
# Requirement already satisfied: typing_extensions>=4.0 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from pypdf) (4.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Vi trenger flere pakker til å jobbe med LangChain og HuggingFace:

# %%
pip install --upgrade langchain-ollama langchain-community
# Out:
# Requirement already satisfied: langchain-ollama in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (0.3.10)
# Requirement already satisfied: langchain-community in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (0.3.31)
# Requirement already satisfied: ollama<1.0.0,>=0.5.3 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from langchain-ollama) (0.6.2)
# Requirement already satisfied: langchain-core<2.0.0,>=0.3.76 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from langchain-ollama) (0.3.86)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from langchain-core<2.0.0,>=0.3.76->langchain-ollama) (0.4.37)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from langchain-core<2.0.0,>=0.3.76->langchain-ollama) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from langchain-core<2.0.0,>=0.3.76->langchain-ollama) (1.33)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from langchain-core<2.0.0,>=0.3.76->langchain-ollama) (6.0.3)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from langchain-core<2.0.0,>=0.3.76->langchain-ollama) (4.16.0)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from langchain-core<2.0.0,>=0.3.76->langchain-ollama) (25.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from langchain-core<2.0.0,>=0.3.76->langchain-ollama) (2.13.4)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from langchain-core<2.0.0,>=0.3.76->langchain-ollama) (0.15.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=0.3.76->langchain-ollama) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=0.3.76->langchain-ollama) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=0.3.76->langchain-ollama) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=0.3.76->langchain-ollama) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=0.3.76->langchain-ollama) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=0.3.76->langchain-ollama) (0.25.0)
# Requirement already satisfied: anyio in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=0.3.76->langchain-ollama) (4.12.1)
# Requirement already satisfied: certifi in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=0.3.76->langchain-ollama) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=0.3.76->langchain-ollama) (1.0.9)
# Requirement already satisfied: idna in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=0.3.76->langchain-ollama) (3.18)
# Requirement already satisfied: h11>=0.16 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=0.3.76->langchain-ollama) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=0.3.76->langchain-ollama) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=0.3.76->langchain-ollama) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=0.3.76->langchain-ollama) (0.4.2)
# Requirement already satisfied: langchain<2.0.0,>=0.3.27 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from langchain-community) (0.3.30)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from langchain-community) (2.0.51)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from langchain-community) (3.13.5)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from langchain-community) (2.11.0)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from langchain-community) (2.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.22.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from langchain<2.0.0,>=0.3.27->langchain-community) (0.3.11)
# Requirement already satisfied: python-dotenv>=0.21.0 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=0.3.76->langchain-ollama) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=0.3.76->langchain-ollama) (2.6.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=0.3.76->langchain-ollama) (1.3.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade langchain langgraph # langchain-classic
# Out:
# Requirement already satisfied: langchain in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (0.3.30)
# Collecting langgraph
#   Downloading langgraph-0.6.11-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.85 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from langchain) (0.3.86)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from langchain) (0.3.11)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.17 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from langchain) (0.4.37)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from langchain) (2.13.4)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from langchain) (2.0.51)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from langchain) (2.32.5)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from langchain) (6.0.3)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from langchain) (4.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from langchain-core<1.0.0,>=0.3.85->langchain) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from langchain-core<1.0.0,>=0.3.85->langchain) (1.33)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from langchain-core<1.0.0,>=0.3.85->langchain) (4.16.0)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from langchain-core<1.0.0,>=0.3.85->langchain) (25.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from langchain-core<1.0.0,>=0.3.85->langchain) (0.15.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<1.0.0,>=0.3.85->langchain) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from langsmith<1.0.0,>=0.1.17->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from langsmith<1.0.0,>=0.1.17->langchain) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from langsmith<1.0.0,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from langsmith<1.0.0,>=0.1.17->langchain) (0.25.0)
# Requirement already satisfied: anyio in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.17->langchain) (4.12.1)
# Requirement already satisfied: certifi in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.17->langchain) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.17->langchain) (1.0.9)
# Requirement already satisfied: idna in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.17->langchain) (3.18)
# Requirement already satisfied: h11>=0.16 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.17->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from requests<3.0.0,>=2.0.0->langchain) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from requests<3.0.0,>=2.0.0->langchain) (2.6.3)
# Collecting langgraph-checkpoint<4.0.0,>=2.1.0 (from langgraph)
#   Downloading langgraph_checkpoint-2.1.2-py3-none-any.whl.metadata (4.2 kB)
# Collecting langgraph-prebuilt<0.7.0,>=0.6.0 (from langgraph)
#   Downloading langgraph_prebuilt-0.6.5-py3-none-any.whl.metadata (4.5 kB)
# Collecting langgraph-sdk<0.3.0,>=0.2.2 (from langgraph)
#   Downloading langgraph_sdk-0.2.9-py3-none-any.whl.metadata (1.5 kB)
# Collecting xxhash>=3.5.0 (from langgraph)
#   Downloading xxhash-3.8.1-cp39-cp39-macosx_11_0_arm64.whl.metadata (15 kB)
# Collecting ormsgpack>=1.10.0 (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph)
#   Downloading ormsgpack-1.11.0-cp39-cp39-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl.metadata (1.2 kB)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.17->langchain) (1.3.1)
# Downloading langgraph-0.6.11-py3-none-any.whl (155 kB)
# Downloading langgraph_checkpoint-2.1.2-py3-none-any.whl (45 kB)
# Downloading langgraph_prebuilt-0.6.5-py3-none-any.whl (28 kB)
# Downloading langgraph_sdk-0.2.9-py3-none-any.whl (56 kB)
# Downloading ormsgpack-1.11.0-cp39-cp39-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl (367 kB)
# Downloading xxhash-3.8.1-cp39-cp39-macosx_11_0_arm64.whl (32 kB)
# Installing collected packages: xxhash, ormsgpack, langgraph-sdk, langgraph-checkpoint, langgraph-prebuilt, langgraph
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6 [langgraph]
# Successfully installed langgraph-0.6.11 langgraph-checkpoint-2.1.2 langgraph-prebuilt-0.6.5 langgraph-sdk-0.2.9 ormsgpack-1.11.0 xxhash-3.8.1
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Transformers er den grunnleggende teknologien som brukes i store språkmodeller. Derfor installerer vi biblioteket `sentence-transformers`:

# %%
pip install --upgrade transformers sentence-transformers
# Out:
# Requirement already satisfied: transformers in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (4.57.6)
# Requirement already satisfied: sentence-transformers in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (5.1.2)
# Requirement already satisfied: filelock in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from transformers) (3.19.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from transformers) (0.36.2)
# Requirement already satisfied: numpy>=1.17 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from transformers) (2026.1.15)
# Requirement already satisfied: requests in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from transformers) (2.32.5)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from transformers) (0.22.2)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from transformers) (4.70.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.10.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.5.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.16.0)
# Requirement already satisfied: torch>=1.11.0 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from sentence-transformers) (2.8.0)
# Requirement already satisfied: scikit-learn in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from sentence-transformers) (1.6.1)
# Requirement already satisfied: scipy in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: Pillow in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from sentence-transformers) (11.3.0)
# Requirement already satisfied: sympy>=1.13.3 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers) (3.2.1)
# Requirement already satisfied: jinja2 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from requests->transformers) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from requests->transformers) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from requests->transformers) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from requests->transformers) (2026.7.22)
# Requirement already satisfied: joblib>=1.2.0 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from scikit-learn->sentence-transformers) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Noen modeller bruker `sentencepiece` biblioteket. Derfor installerer vi dette også:

# %%
pip install --upgrade sentencepiece
# Out:
# Collecting sentencepiece
#   Downloading sentencepiece-0.2.2-cp39-cp39-macosx_11_0_arm64.whl.metadata (33 kB)
# Downloading sentencepiece-0.2.2-cp39-cp39-macosx_11_0_arm64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 16.3 MB/s  0:00:00
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.2.2
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Programvare til å lese tekstdokumenter
#
# Vi kommer til å bruke [unstructured](https://python.langchain.com/docs/integrations/providers/unstructured/) til å lese dokumenter. Unstructured støtter ulike dokumentformater, som PDFer, Word filer og rene tekstdokumenter:

# %%
pip install --upgrade unstructured[pdf]==0.18.24 langchain-unstructured requests
# Out:
# zsh:1: no matches found: unstructured[pdf]==0.18.24
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Søkeindeks
#
# Til [Retrieval-Augmented Generation (RAG)](05_rag.ipynb) kapittelet vil vi bruke [FAISS](https://faiss.ai/) til å søke etter dokumenter lokalt på maskinen:

# %%
pip install --upgrade faiss-cpu
# Out:
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.13.0-cp39-abi3-macosx_14_0_arm64.whl.metadata (7.7 kB)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from faiss-cpu) (2.0.2)
# Requirement already satisfied: packaging in /Users/ragnhildsundsbak/rtd-tutorial/.venv/lib/python3.9/site-packages (from faiss-cpu) (25.0)
# Downloading faiss_cpu-1.13.0-cp39-abi3-macosx_14_0_arm64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 9.6 MB/s  0:00:00m eta 0:00:01
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.13.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Språkmodellen
#
# Vi kommer til å bruke modeller fra [HuggingFace](https://huggingface.co), en nettside som har verktøy og modeller som brukes til maskinlæring. Vi kan bruke åpen- vektmodellene [google/gemma-3-4b-it](https://huggingface.co/google/gemma-3-4b-it) [mistralai/Ministral-8B-Instruct-2410](https://huggingface.co/mistralai/Ministral-8B-Instruct-2410) eller [meta-llama/Llama-3.2-3B-Instruct](https://huggingface.co/meta-llama/Llama-3.2-3B-Instruct) til våre oppgaver.
#
# Ministral-8B-Instruct-2410 har 8 milliarder parametere. Til sammenligning har en av de største språkmodellene når dette skrives, Llama 3.1, 405 milliarder parametere. Ministral-8B-Instruct-2410 har rundt 16 GB, noe som fortsatt gjør den til en ganske stor modell. For å kjøre den, må vi ha en GPU med minst 20 GB minne. Vi må også ha minne til programvare og datahåndtering. Dette er grunnen til at man i praksis må ha 40 GB minne.
#
# Modellen kan også kjøre på CPU, men da vil det gå tregere.

# %% [markdown]
# ## Modellens plassering
#
# Vi bør fortelle HuggingFace biblioteket hvor det skal lagre dataene sine. Hvis du kjører på Educloud/Fox prosjekt ec443 finner du modellen på stien nedenfor. Dersom du kjører på din egen manskin, trenger du antakelig ikke å spesifisere modellens plassering:

# %%
#import os
#os.environ['HF_HOME'] = '/fp/projects01/ec443/huggingface/cache/'

# %% [markdown]
# ```{admonition} 3.2: Frivillig oppgave:
#
# Hvis du kjører en av modellene som allerede er lastet ned til Educloud/Fox prosjekt ec443, kan du droppe dette. Hvis du ikke kjører på Educloud/Fox project ec443, eller du vil bruke en modell som ikke er lastet ned, må du laste den.
#
# Du trenger “User Access Token” fra HuggingFace. Hvis du ikke har en konto på HuggingFace, må du først registrere deg. Klikk på knappen “Sign Up” i øvre høyre hjørne på HuggingFace’ nettside.
#
# Når du har logget inn med din brukerkonto, kan du lage et [User Access Token](https://huggingface.co/settings/tokens), som gir lesetilgang ved å følge denne [guiden](https://huggingface.co/docs/hub/en/security-tokens):
#
# ```{code} python
# :caption: Innlogging i på Huggingface i JupyterLab
# from huggingface_hub import login
# login()
# ``````

# %% [markdown]
# (bonus-venv)=
# ## Bonus: Virtuelle miljøer
#
# Som standard, vil `pip` kommandoen installere Python moduler eller biblioteker på din brukerprofil, der ditt standard Python miljø ligger. Hvis du bruker Python i forskjellige prosjekter med ulike biblioteker, kan det hende at prosjektene dine behøver ulike versjoner av det samme biblioteket. Python støtter å bytte mellom ulike v ersjoner av samme bibliotek, med _virtuelle miljøer_. Du kan lage ett virtuelt miljø for hvert av dine prosjekter. Deretter installerer du alle biblioteker som hører til i ett spesifikt prosjekt i det virtuelle miljøet for det prosjektet. Det virtuelle miljøet blir ofte lagret i en mappe som heter `.venv`.

# %% [markdown]
# ## Etablering av virtuelt miljø
#
# La oss lage et virtuelt miljø til å kjøre store språkmodeller. Det kan gjøres på mange måter, men vi anbefaler å bruke pythons innebygde `venv` kommando:

# %%
#!python -m venv .venv

# %% [markdown]
# ## Aktivering av miljøet
#
# For å aktivere det virtuelle miljøet i konsollen, kan du bruke et aktiveringsskript:

# %%
#source .venv/bin/activate

# %% [markdown]
# ## JupyterLab kjerne til miljøet
#
# FOr å bruke det virtuelle miljet i JupyterLab, må vi definere en kjerne for det miljøet:

# %%
#! .venv/bin/python -m ipykernel install --user --name LLM --display-name "Python (LLM)"

# %% [markdown]
# ## Bonus: opprenskning av basis venv
#
# Virtuelle miljøer er en bra måte å sikre at du kon har den korrekte programvaren installert, og i rett versjon. Hvis du ønsker å fjerne all programvaren som du tidligere har installert i basismiljøet, kan du bruke denne kommandoen:

# %% [markdown]
# ```{admonition}
# :class: warning
#
# Kommandoen under vil fjerne alle Python pakkene som du har installert med `pip` i basismiljøet.
# ```

# %%
#pip freeze | grep -v file: | xargs pip uninstall -y
