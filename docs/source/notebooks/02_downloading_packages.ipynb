# %% [markdown]
# # Installering
#
# Vi kommer til å bruke [LangChain](https://www.langchain.com/) , et bibliotek med åpen kildekode, som brukes til å lage
# applikasjoner med LLMer. Vi vil bruke modeller fra [HuggingFace](https://huggingface.co/), en nettside som har verktøy og modeller som brukes til maskinlæring.

# %% [markdown]
# ```{admonition} Oppgave 3.1: Lag en ny notebook
#
# Lag en ny Jupyter Notebook med navn `installing` ved å klikke Filmenyen i JupyterLab, og så “New” og “Notebook”. Hvis du blir spurt om å velge en kjerne (kernel), velg “Python 3”. Gi navn til notebooken ved å klikke Filmenyen i JupyterLab og deretter “Rename Notebook”. Bruk navnet `installing`.
# ```
#
# ```{admonition} Virtuelle miljøer
# :class: warning
#
# Hvis du vanligvis jobber med [virtuelle miljøer](https://docs.python.org/3/library/venv.html) på Fox, bør du sette opp og aktivere et virtuelt miljø før du fortsetter. Se i {ref}`bonus-venv`, lenger nede på denne siden. Hvis du ikke har hørt om virtuelle miljøer, kan du fortsette uten å bruke virtuelle miljøer.
# ```

# %% [markdown]
# ## Pyton pakker
#
# Vi kommer til å bruke pakkeinstallasjonsprogrammet ``pip``til å installere programvare. ``pip``installerer programvare fra [Python package index](https://pypi.org/) . Først oppdaterer vi ``pip``til den nyeste versjonen:

# %%
pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in /Users/ragnhildsundsbak/.pyenv/versions/3.11.9/lib/python3.11/site-packages (26.0.1)
# Collecting pip
#   Downloading pip-26.1.2-py3-none-any.whl.metadata (4.6 kB)
# Downloading pip-26.1.2-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 8.1 MB/s  0:00:00m 8.7 MB/s eta 0:00:01
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 26.0.1
#     Uninstalling pip-26.0.1:
#       Successfully uninstalled pip-26.0.1
# Successfully installed pip-26.1.2
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Requirements fil
#
# I desember 2025, hadde vi problemer med at noen av våre viktigste biblioteker ikke lenger ble vedlikeholdt. Dette gjorde at vi utviklet en requirements fil. Behovet for denne gjenoppstod i april 2026. Kjør koden under:

# %%
# pip install -r /fp/projects01/ec443/LLM-requirements.txt

# %% [markdown]
# ```{admonition} Virtuelle miljøer
# :class: warning
#
# Requirements filen gjør at alle pakkene installerer seg selv i en versjon som ikke gir deg problemer. Hopp over resten av dette kapittelet. Skulle du senere ønske å oppdatere python pakkene, kan du kjøre koden under.
# ```

# %% [markdown]
# ### Nevrale nettverk og programvare
#
# Språkmodeller er en slags neurale nettverk. Vi kommer til å bruke Python pakken PyTorch til å kjøre modellene våre.

# %% [markdown]
# ### Generell LLM programvare
#
# Vi kommer til å installere LangChain og HuggingFace programmer først. Vi bruker `huggingface-hub`til å automatisk laste ned modeller når dette nødvendig.

# %%
# pip install --upgrade huggingface-hub
# pip3 uninstall huggingface_hub -y
# Out:
#   Cell In[16], line 2
#     pip3 uninstall huggingface_hub
#          ^
# SyntaxError: invalid syntax

# %%
pip install --upgrade pypdf
# Out:
# Requirement already satisfied: pypdf in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (6.7.5)
# Collecting pypdf
#   Downloading pypdf-6.14.2-py3-none-any.whl.metadata (7.2 kB)
# Downloading pypdf-6.14.2-py3-none-any.whl (349 kB)
# Installing collected packages: pypdf
#   Attempting uninstall: pypdf
#     Found existing installation: pypdf 6.7.5
#     Uninstalling pypdf-6.7.5:
#       Successfully uninstalled pypdf-6.7.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# open-webui 0.8.10 requires langchain==1.2.10, but you have langchain 1.3.14 which is incompatible.
# open-webui 0.8.10 requires langchain-classic==1.0.1, but you have langchain-classic 1.0.8 which is incompatible.
# open-webui 0.8.10 requires langchain-community==0.4.1, but you have langchain-community 0.4.2 which is incompatible.
# open-webui 0.8.10 requires langchain-text-splitters==1.1.1, but you have langchain-text-splitters 1.1.2 which is incompatible.
# open-webui 0.8.10 requires pypdf==6.7.5, but you have pypdf 6.14.2 which is incompatible.
# open-webui 0.8.10 requires sentence-transformers==5.2.3, but you have sentence-transformers 5.6.1 which is incompatible.
# open-webui 0.8.10 requires transformers==5.3.0, but you have transformers 5.14.1 which is incompatible.
# Successfully installed pypdf-6.14.2
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Vi trenger flere pakker til å jobbe med LangChain og HuggingFace:

# %%
pip install --upgrade langchain-ollama
# Out:
# Collecting langchain-ollama
#   Downloading langchain_ollama-1.1.0-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.21 in /Users/ragnhildsundsbak/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langchain-ollama) (1.5.1)
# Collecting ollama<1.0.0,>=0.6.1 (from langchain-ollama)
#   Downloading ollama-0.6.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.21->langchain-ollama) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in /Users/ragnhildsundsbak/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.21->langchain-ollama) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.21->langchain-ollama) (0.7.6)
# Requirement already satisfied: packaging>=23.2.0 in /Users/ragnhildsundsbak/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.21->langchain-ollama) (26.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.21->langchain-ollama) (2.12.5)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.21->langchain-ollama) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.21->langchain-ollama) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /Users/ragnhildsundsbak/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.21->langchain-ollama) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.21->langchain-ollama) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (2.32.5)
# Requirement already satisfied: xxhash>=3.0.0 in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (0.25.0)
# Requirement already satisfied: anyio in /Users/ragnhildsundsbak/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (4.12.1)
# Requirement already satisfied: certifi in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (1.0.9)
# Requirement already satisfied: idna in /Users/ragnhildsundsbak/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (2.6.3)
# Downloading langchain_ollama-1.1.0-py3-none-any.whl (31 kB)
# Downloading ollama-0.6.2-py3-none-any.whl (15 kB)
# Installing collected packages: ollama, langchain-ollama
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [langchain-ollama]
# Successfully installed langchain-ollama-1.1.0 ollama-0.6.2
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade langchain langchain-classic langchain-community langchain-huggingface langgraph
# Out:
# Requirement already satisfied: langchain in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (1.2.10)
# Collecting langchain
#   Downloading langchain-1.3.14-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: langchain-classic in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (1.0.1)
# Collecting langchain-classic
#   Downloading langchain_classic-1.0.8-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: langchain-community in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (0.4.1)
# Collecting langchain-community
#   Downloading langchain_community-0.4.2-py3-none-any.whl.metadata (3.4 kB)
# Collecting langchain-huggingface
#   Downloading langchain_huggingface-1.2.2-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: langgraph in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (1.0.9)
# Collecting langgraph
#   Downloading langgraph-1.2.9-py3-none-any.whl.metadata (4.9 kB)
# Collecting langchain-core<2.0.0,>=1.4.9 (from langchain)
#   Downloading langchain_core-1.5.1-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from langchain) (2.12.5)
# Collecting langgraph-checkpoint<5.0.0,>=4.1.0 (from langgraph)
#   Downloading langgraph_checkpoint-4.1.1-py3-none-any.whl.metadata (5.2 kB)
# Collecting langgraph-prebuilt<1.2.0,>=1.1.0 (from langgraph)
#   Downloading langgraph_prebuilt-1.1.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting langgraph-sdk<0.5.0,>=0.4.2 (from langgraph)
#   Downloading langgraph_sdk-0.4.2-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: xxhash>=3.5.0 in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from langgraph) (3.6.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (1.33)
# Collecting langchain-protocol>=0.0.17 (from langchain-core<2.0.0,>=1.4.9->langchain)
#   Downloading langchain_protocol-0.0.18-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (0.7.6)
# Requirement already satisfied: packaging>=23.2.0 in /Users/ragnhildsundsbak/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (26.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /Users/ragnhildsundsbak/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.9->langchain) (3.0.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph) (3.11.7)
# Requirement already satisfied: websockets<16,>=14 in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph) (15.0.1)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain) (0.25.0)
# Requirement already satisfied: anyio in /Users/ragnhildsundsbak/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph) (4.12.1)
# Requirement already satisfied: certifi in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph) (1.0.9)
# Requirement already satisfied: idna in /Users/ragnhildsundsbak/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Collecting langchain-text-splitters<2.0.0,>=1.1.2 (from langchain-classic)
#   Downloading langchain_text_splitters-1.1.2-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from langchain-classic) (2.0.48)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain) (2.6.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from langchain-community) (3.13.2)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from langchain-community) (2.4.2)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from langchain-community) (2.13.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.22.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.1)
# Requirement already satisfied: huggingface-hub<2.0.0,>=0.33.4 in /Users/ragnhildsundsbak/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langchain-huggingface) (1.25.1)
# Requirement already satisfied: tokenizers<1.0.0,>=0.19.1 in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from langchain-huggingface) (0.22.2)
# Requirement already satisfied: click<9.0.0,>=8.4.2 in /Users/ragnhildsundsbak/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (8.4.2)
# Requirement already satisfied: filelock>=3.10.0 in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (3.24.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (2026.2.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in /Users/ragnhildsundsbak/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (1.5.2)
# Requirement already satisfied: tqdm>=4.42.1 in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (4.67.3)
# Downloading langchain-1.3.14-py3-none-any.whl (139 kB)
# Downloading langgraph-1.2.9-py3-none-any.whl (247 kB)
# Downloading langchain_core-1.5.1-py3-none-any.whl (561 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 561.6/561.6 kB 7.0 MB/s  0:00:00
# Downloading langgraph_checkpoint-4.1.1-py3-none-any.whl (56 kB)
# Downloading langgraph_prebuilt-1.1.0-py3-none-any.whl (41 kB)
# Downloading langgraph_sdk-0.4.2-py3-none-any.whl (160 kB)
# Downloading langchain_classic-1.0.8-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 4.0 MB/s  0:00:008.0 MB/s eta 0:00:01
# Downloading langchain_text_splitters-1.1.2-py3-none-any.whl (35 kB)
# Downloading langchain_community-0.4.2-py3-none-any.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 8.3 MB/s  0:00:00m 8.6 MB/s eta 0:00:01
# Downloading langchain_huggingface-1.2.2-py3-none-any.whl (31 kB)
# Downloading langchain_protocol-0.0.18-py3-none-any.whl (7.2 kB)
# Installing collected packages: langchain-protocol, langchain-core, langgraph-sdk, langgraph-checkpoint, langchain-text-splitters, langchain-huggingface, langgraph-prebuilt, langchain-classic, langgraph, langchain-community, langchain
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 1.2.15
#     Uninstalling langchain-core-1.2.15:
#       Successfully uninstalled langchain-core-1.2.15
#   Attempting uninstall: langgraph-sdk9;38;114m╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  1/11 [langchain-core]
#     Found existing installation: langgraph-sdk 0.3.85;237m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  1/11 [langchain-core]
#     Uninstalling langgraph-sdk-0.3.8:;114m╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  1/11 [langchain-core]
#       Successfully uninstalled langgraph-sdk-0.3.88;5;237m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  1/11 [langchain-core]
#   Attempting uninstall: langgraph-checkpoint━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  1/11 [langchain-core]
#     Found existing installation: langgraph-checkpoint 4.0.0━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  1/11 [langchain-core]
#     Uninstalling langgraph-checkpoint-4.0.0:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  1/11 [langchain-core]
#       Successfully uninstalled langgraph-checkpoint-4.0.0m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  1/11 [langchain-core]
#   Attempting uninstall: langchain-text-splitters━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  1/11 [langchain-core]
#     Found existing installation: langchain-text-splitters 1.1.1━━━━━━━━━━━━━━━━━━━━━━━━━  4/11 [langchain-text-splitters]
#     Uninstalling langchain-text-splitters-1.1.1:;114m╸━━━━━━━━━━━━━━━━━━━━━━━━━  4/11 [langchain-text-splitters]
#       Successfully uninstalled langchain-text-splitters-1.1.18;5;237m━━━━━━━━━━━━━━━━━━━━━━━━━  4/11 [langchain-text-splitters]
#   Attempting uninstall: langgraph-prebuilt249;38;114m╸━━━━━━━━━━━━━━━━━━━━━━━━━  4/11 [langchain-text-splitters]
#     Found existing installation: langgraph-prebuilt 1.0.8m━━━━━━━━━━━━━━━━━━━━━━━━━  4/11 [langchain-text-splitters]
#     Uninstalling langgraph-prebuilt-1.0.8:249;38;114m╸━━━━━━━━━━━━━━━━━━━━━━━━━  4/11 [langchain-text-splitters]
#       Successfully uninstalled langgraph-prebuilt-1.0.8━━━━━━━━━━━━━━━━━━━━━━━━━  4/11 [langchain-text-splitters]
#   Attempting uninstall: langchain-classic;249;38;114m╸━━━━━━━━━━━━━━━━━━━━━━━━━  4/11 [langchain-text-splitters]
#     Found existing installation: langchain-classic 1.0.10m━━━━━━━━━━━━━━━━━━━━━━━━━  4/11 [langchain-text-splitters]
#     Uninstalling langchain-classic-1.0.1:;249;38;114m╸━━━━━━━━━━━━━━━━━━━━━━━━━  4/11 [langchain-text-splitters]
#       Successfully uninstalled langchain-classic-1.0.1━━━━━━━━━━━━━━━━━━━━━━━━━  4/11 [langchain-text-splitters]
#   Attempting uninstall: langgraph━━━━━━━━━━━━━╺━━━━━━━━━━━━━━  7/11 [langchain-classic]splitters]
#     Found existing installation: langgraph 1.0.938;5;237m╺━━━━━━━━━━━━━━  7/11 [langchain-classic]
#     Uninstalling langgraph-1.0.9:━━━━━━━━━╺━━━━━━━━━━━━━━  7/11 [langchain-classic]
#       Successfully uninstalled langgraph-1.0.9╺━━━━━━━━━━━━━━  7/11 [langchain-classic]
#   Attempting uninstall: langchain-community━━━━━━━╺━━━━━━━━━━  8/11 [langgraph]sic]
#     Found existing installation: langchain-community 0.4.137m╺━━━━━━━━━━  8/11 [langgraph]
#     Uninstalling langchain-community-0.4.1:━━━╺━━━━━━━━━━  8/11 [langgraph]
#       Successfully uninstalled langchain-community-0.4.1;237m╺━━━━━━━━━━  8/11 [langgraph]
#   Attempting uninstall: langchain━━━━━━━━━━━━━━━━━━━━╸━━━━━━━  9/11 [langchain-community]
#     Found existing installation: langchain 1.2.10╸━━━━━━━  9/11 [langchain-community]
#     Uninstalling langchain-1.2.10:━━━━━━━━━━━━━━━╸━━━━━━━  9/11 [langchain-community]
#       Successfully uninstalled langchain-1.2.10━━╸━━━━━━━  9/11 [langchain-community]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11/11 [langchain]━━  9/11 [langchain-community]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# open-webui 0.8.10 requires langchain==1.2.10, but you have langchain 1.3.14 which is incompatible.
# open-webui 0.8.10 requires langchain-classic==1.0.1, but you have langchain-classic 1.0.8 which is incompatible.
# open-webui 0.8.10 requires langchain-community==0.4.1, but you have langchain-community 0.4.2 which is incompatible.
# open-webui 0.8.10 requires langchain-text-splitters==1.1.1, but you have langchain-text-splitters 1.1.2 which is incompatible.
# Successfully installed langchain-1.3.14 langchain-classic-1.0.8 langchain-community-0.4.2 langchain-core-1.5.1 langchain-huggingface-1.2.2 langchain-protocol-0.0.18 langchain-text-splitters-1.1.2 langgraph-1.2.9 langgraph-checkpoint-4.1.1 langgraph-prebuilt-1.1.0 langgraph-sdk-0.4.2
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Transformers er den grunnleggende teknologien som brukes i store språkmodeller. Derfor installerer vi biblioteket `sentence-transformers`:

# %%
pip install --upgrade transformers sentence-transformers
# Out:
# Requirement already satisfied: transformers in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (5.3.0)
# Collecting transformers
#   Downloading transformers-5.14.1-py3-none-any.whl.metadata (32 kB)
# Requirement already satisfied: sentence-transformers in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (5.2.3)
# Collecting sentence-transformers
#   Downloading sentence_transformers-5.6.1-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: huggingface-hub<2.0,>=1.5.0 in /Users/ragnhildsundsbak/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from transformers) (1.25.1)
# Requirement already satisfied: numpy>=1.17 in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from transformers) (2.4.2)
# Requirement already satisfied: packaging>=20.0 in /Users/ragnhildsundsbak/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from transformers) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex>=2025.10.22 in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from transformers) (2026.2.19)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from transformers) (0.24.1)
# Collecting safetensors>=0.8.0 (from transformers)
#   Downloading safetensors-0.8.0-cp310-abi3-macosx_11_0_arm64.whl.metadata (4.2 kB)
# Requirement already satisfied: tqdm>=4.60 in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from transformers) (4.67.3)
# Requirement already satisfied: click<9.0.0,>=8.4.2 in /Users/ragnhildsundsbak/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (8.4.2)
# Requirement already satisfied: filelock>=3.10.0 in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (3.24.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (2026.2.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in /Users/ragnhildsundsbak/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (1.5.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (0.28.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /Users/ragnhildsundsbak/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (4.15.0)
# Requirement already satisfied: anyio in /Users/ragnhildsundsbak/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (4.12.1)
# Requirement already satisfied: certifi in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (1.0.9)
# Requirement already satisfied: idna in /Users/ragnhildsundsbak/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (0.16.0)
# Requirement already satisfied: torch>=1.11.0 in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from sentence-transformers) (2.10.0)
# Requirement already satisfied: scikit-learn>=0.22.0 in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from sentence-transformers) (1.8.0)
# Requirement already satisfied: scipy>=1.0.0 in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from sentence-transformers) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from scikit-learn>=0.22.0->sentence-transformers) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from scikit-learn>=0.22.0->sentence-transformers) (3.6.0)
# Requirement already satisfied: sympy>=1.13.3 in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (3.6.1)
# Requirement already satisfied: jinja2 in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from typer->transformers) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from typer->transformers) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from typer->transformers) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from rich>=12.3.0->typer->transformers) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/ragnhildsundsbak/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from rich>=12.3.0->typer->transformers) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->transformers) (0.1.2)
# Downloading transformers-5.14.1-py3-none-any.whl (11.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 6.5 MB/s  0:00:01m 6.9 MB/s eta 0:00:01
# Downloading sentence_transformers-5.6.1-py3-none-any.whl (596 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 596.7/596.7 kB 6.5 MB/s  0:00:00
# Downloading safetensors-0.8.0-cp310-abi3-macosx_11_0_arm64.whl (484 kB)
# Installing collected packages: safetensors, transformers, sentence-transformers
#   Attempting uninstall: safetensors
#     Found existing installation: safetensors 0.7.0
#     Uninstalling safetensors-0.7.0:
#       Successfully uninstalled safetensors-0.7.0
#   Attempting uninstall: transformers
#     Found existing installation: transformers 5.3.0
#     Uninstalling transformers-5.3.0:
#       Successfully uninstalled transformers-5.3.0
#   Attempting uninstall: sentence-transformers237m╺━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/3 [transformers]
#     Found existing installation: sentence-transformers 5.2.3m━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/3 [transformers]
#     Uninstalling sentence-transformers-5.2.3:╺━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/3 [transformers]
#       Successfully uninstalled sentence-transformers-5.2.337m━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/3 [transformers]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [sentence-transformers] 2/3 [sentence-transformers]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# open-webui 0.8.10 requires langchain==1.2.10, but you have langchain 1.3.14 which is incompatible.
# open-webui 0.8.10 requires langchain-classic==1.0.1, but you have langchain-classic 1.0.8 which is incompatible.
# open-webui 0.8.10 requires langchain-community==0.4.1, but you have langchain-community 0.4.2 which is incompatible.
# open-webui 0.8.10 requires langchain-text-splitters==1.1.1, but you have langchain-text-splitters 1.1.2 which is incompatible.
# open-webui 0.8.10 requires sentence-transformers==5.2.3, but you have sentence-transformers 5.6.1 which is incompatible.
# open-webui 0.8.10 requires transformers==5.3.0, but you have transformers 5.14.1 which is incompatible.
# Successfully installed safetensors-0.8.0 sentence-transformers-5.6.1 transformers-5.14.1
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Noen modeller bruker `sentencepiece` biblioteket. Derfor installerer vi dette også:

# %%
pip install --upgrade sentencepiece
# Out:
# Requirement already satisfied: sentencepiece in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (0.2.1)
# Collecting sentencepiece
#   Downloading sentencepiece-0.2.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (33 kB)
# Downloading sentencepiece-0.2.2-cp311-cp311-macosx_11_0_arm64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 7.2 MB/s  0:00:00
# Installing collected packages: sentencepiece
#   Attempting uninstall: sentencepiece
#     Found existing installation: sentencepiece 0.2.1
#     Uninstalling sentencepiece-0.2.1:
#       Successfully uninstalled sentencepiece-0.2.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# open-webui 0.8.10 requires langchain==1.2.10, but you have langchain 1.3.14 which is incompatible.
# open-webui 0.8.10 requires langchain-classic==1.0.1, but you have langchain-classic 1.0.8 which is incompatible.
# open-webui 0.8.10 requires langchain-community==0.4.1, but you have langchain-community 0.4.2 which is incompatible.
# open-webui 0.8.10 requires langchain-text-splitters==1.1.1, but you have langchain-text-splitters 1.1.2 which is incompatible.
# open-webui 0.8.10 requires sentence-transformers==5.2.3, but you have sentence-transformers 5.6.1 which is incompatible.
# open-webui 0.8.10 requires transformers==5.3.0, but you have transformers 5.14.1 which is incompatible.
# Successfully installed sentencepiece-0.2.2
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Programvare til å lese tekstdokumenter
#
# Vi kommer til å bruke [unstructured](https://python.langchain.com/docs/integrations/providers/unstructured/) til å lese dokumenter. Unstructured støtter ulike dokumentformater, som PDFer, Word filer og rene tekstdokumenter:

# %%
pip install --upgrade unstructured[pdf]==0.18.24 langchain-unstructured requests
# Out:
# zsh:1: no matches found: unstructured[pdf]==0.18.24
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Søkeindeks
#
# Til [Retrieval-Augmented Generation (RAG)](05_rag.ipynb) kapittelet vil vi bruke [FAISS](https://faiss.ai/) til å søke etter dokumenter lokalt på maskinen:

# %%
pip install --upgrade faiss-cpu
# Out:
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.14.3-cp310-abi3-macosx_14_0_arm64.whl.metadata (7.8 kB)
# Requirement already satisfied: numpy>=1.25 in /Users/ragnhildsundsbak/.local/lib/python3.11/site-packages (from faiss-cpu) (2.4.2)
# Requirement already satisfied: packaging in /Users/ragnhildsundsbak/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from faiss-cpu) (26.0)
# Downloading faiss_cpu-1.14.3-cp310-abi3-macosx_14_0_arm64.whl (4.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 6.4 MB/s  0:00:00 eta 0:00:010:01
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.14.3
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Språkmodellen
#
# Vi kommer til å bruke modeller fra [HuggingFace](https://huggingface.co), en nettside som har verktøy og modeller som brukes til maskinlæring. Vi kan bruke åpen- vektmodellene [google/gemma-3-4b-it](https://huggingface.co/google/gemma-3-4b-it) [mistralai/Ministral-8B-Instruct-2410](https://huggingface.co/mistralai/Ministral-8B-Instruct-2410) eller [meta-llama/Llama-3.2-3B-Instruct](https://huggingface.co/meta-llama/Llama-3.2-3B-Instruct) til våre oppgaver.
#
# Ministral-8B-Instruct-2410 har 8 milliarder parametere. Til sammenligning har en av de største språkmodellene når dette skrives, Llama 3.1, 405 milliarder parametere. Ministral-8B-Instruct-2410 har rundt 16 GB, noe som fortsatt gjør den til en ganske stor modell. For å kjøre den, må vi ha en GPU med minst 20 GB minne. Vi må også ha minne til programvare og datahåndtering. Dette er grunnen til at man i praksis må ha 40 GB minne.
#
# Modellen kan også kjøre på CPU, men da vil det gå tregere.

# %% [markdown]
# ## Modellens plassering
#
# Vi bør fortelle HuggingFace biblioteket hvor det skal lagre dataene sine. Hvis du kjører på Educloud/Fox prosjekt ec443 finner du modellen på stien nedenfor. Dersom du kjører på din egen manskin, trenger du antakelig ikke å spesifisere modellens plassering:

# %%
#import os
#os.environ['HF_HOME'] = '/fp/projects01/ec443/huggingface/cache/'

# %% [markdown]
# ```{admonition} 3.2: Frivillig oppgave:
#
# Hvis du kjører en av modellene som allerede er lastet ned til Educloud/Fox prosjekt ec443, kan du droppe dette. Hvis du ikke kjører på Educloud/Fox project ec443, eller du vil bruke en modell som ikke er lastet ned, må du laste den.
#
# Du trenger “User Access Token” fra HuggingFace. Hvis du ikke har en konto på HuggingFace, må du først registrere deg. Klikk på knappen “Sign Up” i øvre høyre hjørne på HuggingFace’ nettside.
#
# Når du har logget inn med din brukerkonto, kan du lage et [User Access Token](https://huggingface.co/settings/tokens), som gir lesetilgang ved å følge denne [guiden](https://huggingface.co/docs/hub/en/security-tokens):
#
# ```{code} python
# :caption: Innlogging i på Huggingface i JupyterLab
# from huggingface_hub import login
# login()
# ``````

# %% [markdown]
# (bonus-venv)=
# ## Bonus: Virtuelle miljøer
#
# Som standard, vil `pip` kommandoen installere Python moduler eller biblioteker på din brukerprofil, der ditt standard Python miljø ligger. Hvis du bruker Python i forskjellige prosjekter med ulike biblioteker, kan det hende at prosjektene dine behøver ulike versjoner av det samme biblioteket. Python støtter å bytte mellom ulike v ersjoner av samme bibliotek, med _virtuelle miljøer_. Du kan lage ett virtuelt miljø for hvert av dine prosjekter. Deretter installerer du alle biblioteker som hører til i ett spesifikt prosjekt i det virtuelle miljøet for det prosjektet. Det virtuelle miljøet blir ofte lagret i en mappe som heter `.venv`.

# %% [markdown]
# ## Etablering av virtuelt miljø
#
# La oss lage et virtuelt miljø til å kjøre store språkmodeller. Det kan gjøres på mange måter, men vi anbefaler å bruke pythons innebygde `venv` kommando:

# %%
#!python -m venv .venv

# %% [markdown]
# ## Aktivering av miljøet
#
# For å aktivere det virtuelle miljøet i konsollen, kan du bruke et aktiveringsskript:

# %%
#source .venv/bin/activate

# %% [markdown]
# ## JupyterLab kjerne til miljøet
#
# FOr å bruke det virtuelle miljet i JupyterLab, må vi definere en kjerne for det miljøet:

# %%
#! .venv/bin/python -m ipykernel install --user --name LLM --display-name "Python (LLM)"

# %% [markdown]
# ## Bonus: opprenskning av basis venv
#
# Virtuelle miljøer er en bra måte å sikre at du kon har den korrekte programvaren installert, og i rett versjon. Hvis du ønsker å fjerne all programvaren som du tidligere har installert i basismiljøet, kan du bruke denne kommandoen:

# %% [markdown]
# ```{admonition}
# :class: warning
#
# Kommandoen under vil fjerne alle Python pakkene som du har installert med `pip` i basismiljøet.
# ```

# %%
#pip freeze | grep -v file: | xargs pip uninstall -y
