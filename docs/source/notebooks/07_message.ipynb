# %% [markdown]
# # Important messages
#
# ## E-mail nr 1.
#
# ### Title: **Important** :Required preparations for "Run LLMs on Educloud UiO", Digital Scholarship days
#
# Title: **Important** :Required preparations for "Run LLMs on Educloud UiO", Digital Scholarship days
#
# Hi Everyone,
#
# Welcome to Digital Scholarship Days 2026 and Run Large Language Models on Educloud UiO.
#
# There are important preparations for our course wich is held as part of Digital Scholarship days, Run LLMs on Educloud UiO.
#
# In order to follow the course, it is essential that everyone has logged into Educloud. This is where we are going to work. The url is: [https://ood.educloud.no ](https://ood.educloud.no).
#
# In order to enter, you need the Url for signing up and [applying for group membership](https://selfservice.educloud.no/membership-application).
#
# We need all of you to apply for group membership in ec443. This is why we have made [this thorough guide](https://llm-course-eng.readthedocs.io/en/latest/notebooks/01_preparations.html).
#
# We will make room for meeting with those of you who have questions regarding these practical issues, right after the x-mas holiday. But before that, please try it on your own!
# Please do not hesitate sending me an email, if you have comments on this procedure, as i look forward to reading some email also during the holiday.
#
# Have a very merry x-mas to everyone!
#
# Best wishes from the LLM-team
# Oslo University Library
#
# ## E-mail nr 2.
#
# ### Title: Important preparations for “Run LLMs on Educloud UiO”, Digital Scholarship days
#
# Hi Everyone,
#
# Welcome to Digital Scholarship Days 2026 and Run Large Language Models on Educloud UiO.
#
# There are important preparations for our course, Run LLMs on Educloud UiO. [Test this link](https://ondemand.educloud.no/pun/sys/dashboard) for Educloud on demand. If unable to log in, you probably need to read the [preparation guide](https://llm-course-eng.readthedocs.io/en/latest/notebooks/01_preparations.html). We strongly encourage you to do so, since it will make you able to participate actively in the lesson.
#
# Best wishes from the LLM-team Oslo University Library
#
# ## E-mail nr 3.
#
# ### Title: Preparations for “Run LLMs on Educloud UiO”, Digital Scholarship days/ Forberedelser til kurset “Run LLMs on Educloud UiO”, Digital Scholarship days
#
# Hei til alle,
# Dere som får denne meldingen er ikke inne i gruppen ec443. Jeg håper å få inn flere søknader om medlemskap i dag. Grunnen er at jeg håper vi kan bruke morgendagen på å teste innlogging med [Microsoft Authenticator](https://www.uio.no/english/services/it/research/platforms/edu-research/help/two-factor-authentication.html)
#
# For at dere skal kunne gjøre dette, må dere først lese [de to foregående](https://llm-course-eng.readthedocs.io/en/latest/notebooks/07_message.html) epostene som kom fra meg, den siste datert 2. januar 2026 med tittel ": Important preparations for “Run LLMs on Educloud UiO”", og gjøre det som beskrives. Når jeg ser at dere er inne i gruppen, vil jeg slutte å spamme dere i mailen :).
#
# Ta gjerne kontakt på min epost eller telefon, dersom du har spørsmål.
#
# Beste hilsen Ragnhild Sundsbak
# tel +47 90643192
