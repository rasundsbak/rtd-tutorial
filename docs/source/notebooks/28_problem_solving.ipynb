# %% [markdown]
# # Problem solving
#
# Based on problems and solutions from the community.

# %% [markdown]
# ## Testing code WIP
#
# ###
# I am working in the [myst sandbox](https://mystmd.org/sandbox)
#
# ```{admonition} This is my admonition
# This is my note
# ```
#
# ```{note} Notes require **no** arguments, so content can start here.
# ```
#
#
# ```{warning}
# Here's my warning
# ```
#
# ```{note}`dropdown`
# Here is a note!
# ```
#
# :::{tip}`dropdown`
# Here is a note!
# :::
#
#
# ## Colon fence
#
# :::{tip}`dropdown`
# Here is a note!
# :::
#
# :::{note}
# :class: dropdown
# Here is a note!
# :::
#
# :::{hint}
# :class: dropdown
# Here is a note!
# :::
#
# :::{hint}
# :class: dropdown
# :open: true
# Here is a note!
# :::
#
# **Alias:** attention, caution, danger, error, important, hint, note, seealso, tip, warning
#
# **class (string)**
#
#     CSS classes to add to your admonition. Special classes include:
#
#         dropdown: turns the admonition into a <details> html element
#
#         simple: an admonition with “simple” styles
#
#         the name of an admonition, the first valid admonition name encountered will be used (e.g. tip). Note that if you provide conflicting class names, the first valid admonition name will be used.

# %% [markdown]
# code view 1:
#
#     !pip install --upgrade pip
#
# Note: Do not use --upgrade pip in this lesson. The reason is that ce have some specific versions as requirements. A total upgrade would make the process break from the hatbot chapter onwards.
#
# code view 2:
#
#     # reset the main to match the main
#     # local changes will be removed
#     # use only if you have backup on the changes you want to keep
#     git reset --hard origin/main
#
# code view 3:
#
#     # fetch and downnoad content from the remote repository, and update on your local
#     git pull
#
# code view 4:
#
#     # See what is changed:
#     git log --oneline
#
# code view 5:
#
#     # Where are my kernels?
#     $ jupyter kernelspec list
#
#     Available kernels:
#       llm        /fp/homes01/u01/[your username]/.local/share/jupyter/kernels/llm
#       python3    /cluster/software/EL9/easybuild/software/jupyter-server/2.14.0-GCCcore-13.2.0/share/jupyter/kernels/python3
#
# code view 6:
#
#     # Setting up the remote again (use if it does not respind to the reset for instance):
#     git remote add origin https://github.com/uio-library/LLM-course.git
#
# code view 7:
#
#     # fetch and merge updates
#     git fetch origin
#     git merge origin/main
#
# code view 8:
#
#     # alternative to above
#     git pull origin main
#
# code view 9:
