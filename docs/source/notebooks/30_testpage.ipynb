# %% [markdown]
# # Testing page
# ## Callouts and admonitions
#
# ```{admonition} Virtuelle miljøer
# :class: warning
#
# Oransje - Lorem ipsum dolor sit amet, consectetur adipiscing elit. Integer eu sem eros. Maecenas porttitor ligula et sollicitudin sagittis. Nulla imperdiet ante quam, nec malesuada eros auctor egestas.
# ```
#
#
#
# ```{warning} Virtuelle miljøer
#
# Oransje - Hvis du vanligvis jobber med [virtuelle miljøer](https://docs.python.org/3/library/venv.html) på Fox, bør du sette opp og aktivere et virtuelt miljø før du fortsetter. Se i {ref}`bonus-venv`, lenger nede på denne siden. Hvis du ikke har hørt om virtuelle miljøer, kan du fortsette uten å bruke virtuelle miljøer.
# ```
#
# ```{admonition} Frivillig oppgave:
#
# Blå - Hvis du kjører en av modellene som allerede er lastet ned til Educloud/Fox prosjekt ec443, kan du droppe dette. Hvis du ikke kjører på Educloud/Fox project ec443, eller du vil bruke en modell som ikke er lastet ned, må du laste den.
#
# Du trenger “User Access Token” fra HuggingFace. Hvis du ikke har en konto på HuggingFace, må du først registrere deg. Klikk på knappen “Sign Up” i øvre høyre hjørne på HuggingFace’ nettside.
#
# Når du har logget inn med din brukerkonto, kan du lage et [User Access Token](https://huggingface.co/settings/tokens), som gir lesetilgang ved å følge denne [guiden](https://huggingface.co/docs/hub/en/security-tokens):
#
# ```{code} python
# :caption: Innlogging i på Huggingface i JupyterLab
# from huggingface_hub import login
# login()
# ```
# ```
#
# ```{note} Title
#
# Blå - en note - Content goes here
# ```
#
# ```{admonition} Try again
#
# Admonition med tittel som virker: Lorem ipsum dolor sit amet, consectetur adipiscing elit. Integer eu sem eros. Maecenas porttitor ligula et sollicitudin sagittis. Nulla imperdiet ante quam, nec malesuada eros auctor egestas.
# ```
# ####
#
#
# ```{danger} Virtuelle miljøer
#
# Danger - Hvis du vanligvis jobber med [virtuelle miljøer](https://docs.python.org/3/library/venv.html) på Fox, bør du sette opp og aktivere et virtuelt miljø før du fortsetter. Se i {ref}`bonus-venv`, lenger nede på denne siden. Hvis du ikke har hørt om virtuelle miljøer, kan du fortsette uten å bruke virtuelle miljøer.
# ```
#
# ```{tip} Helpful tip
# :class: simple
#
# Grønn - This is a tip with a custom title and the "simple" style class.
# ```
#
# ```{tip} Helpful tip
# :class: simple
#
# Grønn - This is a tip with a custom title and the "simple" style class.
# ```
#
# ```{admonition} 1 This is a dropdown title
# :class: dropdown
#
# Blue - admonition w dropdown. This content is hidden by default and can be toggled open.
# ```
#
# ```{attention} 2 This is a dropdown title
# :class: dropdown
#
# Oransje - Obs - This content is hidden by default and can be toggled open.
# ```
#
# ```{admonition} This is not a dropdown title
# :class: warning
#
# Content not hidden.
# ```
#
# ```{caution} This is not a dropdown title
#
# Oransje - blir advarsel - Content not hidden.
# ```
#
# ```{tip} This is not a dropdown title
#
# Content not hidden.
# ```
#
# try: error, important, hint, note, seealso, tip, warning
#
# ## Image w Markdown
#
# ### Markdown opplenking av bilde:
#
# ![copy_cell.png](../copy_cell.png)
#
# ```{admonition} Task 30.1:
# Use copy cell in jupyter lab in order to get e a copy of the
# summarization cell. Change some of the parameters, and see if the output changes.
# ```
#
#
# Try the webpage for [Myst markdown](https://mystmd.org/guide/admonitions)
