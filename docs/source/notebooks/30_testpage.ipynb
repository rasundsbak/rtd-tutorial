# %% [markdown]
# # Testing callouts and admonitions
#
# :::{note} Title
# Content goes here
# :::
#
#
# ```{admonition} Title
# :class: hint
#
# Lorem ipsum dolor sit amet, consectetur adipiscing elit. Integer eu sem eros. Maecenas porttitor ligula et sollicitudin sagittis. Nulla imperdiet ante quam, nec malesuada eros auctor egestas.
# ````
#
# ```{admonition} Title
# :class: caution
#
# Lorem ipsum dolor sit amet, consectetur adipiscing elit. Integer eu sem eros. Maecenas porttitor ligula et sollicitudin sagittis. Nulla imperdiet ante quam, nec malesuada eros auctor egestas.
# ````
#
#
#
#
# ```{admonition} 1 This is a dropdown title
# :class: dropdown
#
# This content is hidden by default and can be toggled open.
# ```
#
# ```{note} This is not a dropdown title
#
# Content not hidden.
# ```
#
# ```{admonition}  2 This is a title
# :class: dropdown
#
# This content is hidden by default and can be toggled open.
# ```
#
#  try: attention, caution, danger, error, important, hint, note, seealso, tip, warning
#
# ```{warning} This is not a dropdown title
#
# Content not hidden.
# ```
#
# ```{caution} 3 This is a title
# :open:
#
# This content is hidden by default and can be toggled open.
# ```
#
#
# ```{tip} This is not a dropdown title
#
# Content not hidden.
# ```
#
# ```{hint} Task 30.1
#
# Lorem ipsum dolor sit amet, consectetur adipiscing elit. Integer eu sem eros. Maecenas porttitor ligula et sollicitudin sagittis. Nulla imperdiet ante quam, nec malesuada eros auctor egestas.
# ```
#
# ```{note} Task 30.1
# :class: dropdown
# :open: true
# Lorem ipsum dolor sit amet, consectetur adipiscing elit. Integer eu sem eros. Maecenas porttitor ligula et sollicitudin sagittis. Nulla imperdiet ante quam, nec malesuada eros auctor egestas.
# ```
#
# ```{hint} Task 30.2
# :class: dropdown
#
# Lorem ipsum dolor sit amet, consectetur adipiscing elit. Integer eu sem eros. Maecenas porttitor ligula et sollicitudin sagittis. Nulla imperdiet ante quam, nec malesuada eros auctor egestas.
# ```
#
#
# ```{important} This is not a dropdown title
#
# Content not hidden. Blabla
# ```
#
# ```{hint} This is not a dropdown title
#
# Content not hidden. Blabla
# ```
#
# ```{caution} This is not a dropdown title
#
# Content not hidden. Blabla
# ```
#
# Try the webpage for [Myst markdown](https://mystmd.org/guide/admonitions)
