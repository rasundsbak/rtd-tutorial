# %% [markdown]
# Notebook created: 2026-03-02 11:27:16
# Generated from: source/30_todo.rst

# %% [markdown]
# <a id='todo'></a>

# %% [markdown]
# # Todo List

# %% [markdown]
# # Todo
#
# Todo 4.1: Vi må legge inn oppgaver der det passer. Det er bedre å erfare enn å lese.
#
# (The [*original entry*](ai_board.ipynb#id1) is located in /Users/ragnhildsundsbak/rtd-tutorial/docs/source/ai_board.rst, line 52.)
